# %%
# !git clone https://github.com/VisualLaser10New/bach-gpt.git

# %%
# %cd bach-gpt
# !pip install -r requirements.txt

# %%
# !python src/scrape_midi.py

# %%
# !python train_pipeline.py --hf-token "" --hf-repo https://huggingface.co/QuelloDell/bach-llama

# %%
# SECURE SSH SETUP (Optional)
# To connect securely, it is highly recommended to use SSH keys instead of passwords:
# 1. Create a public key on your machine
# 2. Uncomment and run the lines below, replacing the placeholder with your public key:
# !mkdir -p /root/.ssh
# !echo "ssh-rsa YOUR_PUBLIC_SSH_KEY" >> /root/.ssh/authorized_keys
# !chmod 700 /root/.ssh && chmod 600 /root/.ssh/authorized_keys
# !apt-get install -y openssh-server
# !mkdir /var/run/sshd
# !echo "PermitRootLogin yes" >> /etc/ssh/sshd_config
# get_ipython().system_raw('/usr/sbin/sshd -D &')
# !apt-get install -y tmate
# !tmate -F
