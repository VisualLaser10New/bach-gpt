# %%
# !pip install -r requirements.txt

# %%
# !python ./src/scrape_midi.py

# %%
# !python train_pipeline.py
# Out:
# ==========================================================
#    J.S. Bach Polyphonic Sheet Music AI Training Pipeline
# ==========================================================
#
# --- Phase 1: Preparing and Augmenting Dataset ---
# Starting data preparation. Processing 1343 files with 12x augmentation...
# Spawning 2 parallel processes for data transposition...
# Augmenting dataset (transposing to 12 keys): 100% 1343/1343 [00:06<00:00, 217.23it/s]
# Data preparation complete. Total files in processed directory: 16116
#
# --- Phase 2: Loading & Training Tokenizer ---
# Initializing a new REMI tokenizer configuration...
# /usr/local/lib/python3.12/dist-packages/miditok/tokenizations/remi.py:88: UserWarning: Attribute controls are not compatible with 'config.one_token_stream_for_programs' and multi-vocabulary tokenizers. Disabling them from the config.
#   super().__init__(tokenizer_config, params)
# Training Byte Pair Encoding (BPE) tokenizer on 1343 files...
# Base vocabulary size: 387, Target vocabulary size: 1887
# [00:00:02] Tokenize words                 ██████████████████ 87688    /    87688[00:00:00] Tokenize words                 ██████████████████ 0        /        0
# [00:00:02] Count pairs                    ██████████████████ 87688    /    87688
# [00:00:10] Compute merges                 ██████████████████ 1499     /     1499
# Saved trained BPE tokenizer to /content/tokenizer.json
#
# --- Phase 3: Preparing PyTorch DataLoaders ---
# Splitting 16116 files into chunks of max length 512...
# Splitting music files (/content/processed/chunks): 100% 16116/16116 [01:03<00:00, 255.55it/s]
# Generated 102216 music chunks for training.
# Dataset split: 81773 training chunks, 20443 validation chunks.
#
# --- Phase 4: Initializing Transformer Model ---
# Initialized GPT-2 model with 11,568,768 trainable parameters.
#
# --- Phase 5: Training Model on CPU ---
# Starting training. Using device: CPU
# Train batches: 2556, Val batches: 639
# Epoch 1/20 [Train]:   0% 0/2556 [00:00<?, ?it/s]^C

# %%
# Install SSH server and set a root password
# !apt-get install -y openssh-server
# !echo "root:colabpassword" | chpasswd
# !mkdir /var/run/sshd
# !echo "PermitRootLogin yes" >> /etc/ssh/sshd_config
# !echo "PasswordAuthentication yes" >> /etc/ssh/sshd_config
get_ipython().system_raw('/usr/sbin/sshd -D &')

# Create a tunnel using a free service like tmate
# !apt-get install -y tmate
# !tmate -F
